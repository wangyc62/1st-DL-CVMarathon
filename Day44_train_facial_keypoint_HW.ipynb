# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Anaconda3\envs\testAI\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1712/1712 [==============================] - 11s 6ms/step - loss: 0.0099 - val_loss: 0.0026
#
# Epoch 00001: val_loss improved from inf to 0.00257, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 0.0024 - val_loss: 0.0021
#
# Epoch 00002: val_loss improved from 0.00257 to 0.00206, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00206 to 0.00191, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00191 to 0.00185, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00185
# Epoch 6/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00185 to 0.00184, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00184 to 0.00177, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.3037e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00177 to 0.00164, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 8.1327e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00164 to 0.00152, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 11s 6ms/step - loss: 7.1531e-04 - val_loss: 0.0015
#
# Epoch 00010: val_loss improved from 0.00152 to 0.00147, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 11s 6ms/step - loss: 6.5322e-04 - val_loss: 0.0014
#
# Epoch 00011: val_loss improved from 0.00147 to 0.00137, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 12s 7ms/step - loss: 6.1348e-04 - val_loss: 0.0013
#
# Epoch 00012: val_loss improved from 0.00137 to 0.00128, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 5.6278e-04 - val_loss: 0.0012
#
# Epoch 00013: val_loss improved from 0.00128 to 0.00121, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 5.4003e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00121 to 0.00114, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 5.0236e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss improved from 0.00114 to 0.00111, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 4.6676e-04 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00111
# Epoch 17/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 4.4619e-04 - val_loss: 0.0010
#
# Epoch 00017: val_loss improved from 0.00111 to 0.00100, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 4.2109e-04 - val_loss: 0.0010
#
# Epoch 00018: val_loss did not improve from 0.00100
# Epoch 19/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 4.0743e-04 - val_loss: 9.7984e-04
#
# Epoch 00019: val_loss improved from 0.00100 to 0.00098, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 3.9191e-04 - val_loss: 9.3220e-04
#
# Epoch 00020: val_loss improved from 0.00098 to 0.00093, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 3.7108e-04 - val_loss: 9.1002e-04
#
# Epoch 00021: val_loss improved from 0.00093 to 0.00091, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.5634e-04 - val_loss: 9.2716e-04
#
# Epoch 00022: val_loss did not improve from 0.00091
# Epoch 23/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.4391e-04 - val_loss: 9.1963e-04
#
# Epoch 00023: val_loss did not improve from 0.00091
# Epoch 24/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 3.3934e-04 - val_loss: 8.8303e-04
#
# Epoch 00024: val_loss improved from 0.00091 to 0.00088, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.2247e-04 - val_loss: 9.2544e-04
#
# Epoch 00025: val_loss did not improve from 0.00088
# Epoch 26/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.2420e-04 - val_loss: 8.7893e-04
#
# Epoch 00026: val_loss improved from 0.00088 to 0.00088, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.0629e-04 - val_loss: 8.4988e-04
#
# Epoch 00027: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 3.0657e-04 - val_loss: 8.7383e-04
#
# Epoch 00028: val_loss did not improve from 0.00085
# Epoch 29/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 3.0243e-04 - val_loss: 8.6670e-04
#
# Epoch 00029: val_loss did not improve from 0.00085
# Epoch 30/150
# 1712/1712 [==============================] - 11s 6ms/step - loss: 2.8700e-04 - val_loss: 8.8764e-04
#
# Epoch 00030: val_loss did not improve from 0.00085
# Epoch 31/150
# 1712/1712 [==============================] - 11s 6ms/step - loss: 2.7865e-04 - val_loss: 8.6118e-04
#
# Epoch 00031: val_loss did not improve from 0.00085
# Epoch 32/150
# 1712/1712 [==============================] - 11s 7ms/step - loss: 2.7976e-04 - val_loss: 8.4340e-04
#
# Epoch 00032: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6853e-04 - val_loss: 8.4375e-04
#
# Epoch 00033: val_loss did not improve from 0.00084
# Epoch 34/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.7264e-04 - val_loss: 8.9627e-04
#
# Epoch 00034: val_loss did not improve from 0.00084
# Epoch 35/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.5539e-04 - val_loss: 8.7874e-04
#
# Epoch 00035: val_loss did not improve from 0.00084
# Epoch 36/150
# 1712/1712 [==============================] - 11s 6ms/step - loss: 2.5472e-04 - val_loss: 8.2395e-04
# Epoch 00036: val_loss improved from 0.00084 to 0.00082, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.4943e-04 - val_loss: 8.0521e-04
#
# Epoch 00037: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.4322e-04 - val_loss: 8.0615e-04
#
# Epoch 00038: val_loss did not improve from 0.00081
# Epoch 39/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.4348e-04 - val_loss: 8.5006e-04
#
# Epoch 00039: val_loss did not improve from 0.00081
# Epoch 40/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.4380e-04 - val_loss: 8.4142e-04
#
# Epoch 00040: val_loss did not improve from 0.00081
# Epoch 41/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.3444e-04 - val_loss: 8.0175e-04
#
# Epoch 00041: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3048e-04 - val_loss: 8.5571e-04
#
# Epoch 00042: val_loss did not improve from 0.00080
# Epoch 43/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.3408e-04 - val_loss: 8.2165e-04
#
# Epoch 00043: val_loss did not improve from 0.00080
# Epoch 44/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.1925e-04 - val_loss: 8.0336e-04
#
# Epoch 00044: val_loss did not improve from 0.00080
# Epoch 45/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.2296e-04 - val_loss: 8.1560e-04
#
# Epoch 00045: val_loss did not improve from 0.00080
# Epoch 46/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.1590e-04 - val_loss: 7.9930e-04
#
# Epoch 00046: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.1398e-04 - val_loss: 8.0813e-04
#
# Epoch 00047: val_loss did not improve from 0.00080
# Epoch 48/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.1531e-04 - val_loss: 8.4163e-04
#
# Epoch 00048: val_loss did not improve from 0.00080
# Epoch 49/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.0987e-04 - val_loss: 8.0476e-04
#
# Epoch 00049: val_loss did not improve from 0.00080
# Epoch 50/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 2.0629e-04 - val_loss: 8.1140e-04
#
# Epoch 00050: val_loss did not improve from 0.00080
# Epoch 51/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 2.0175e-04 - val_loss: 8.0356e-04
#
# Epoch 00051: val_loss did not improve from 0.00080
# Epoch 52/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 2.0149e-04 - val_loss: 7.9174e-04
#
# Epoch 00052: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.9530e-04 - val_loss: 8.1464e-04
#
# Epoch 00053: val_loss did not improve from 0.00079
# Epoch 54/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.9677e-04 - val_loss: 8.3371e-04
#
# Epoch 00054: val_loss did not improve from 0.00079
# Epoch 55/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.9622e-04 - val_loss: 8.3846e-04
#
# Epoch 00055: val_loss did not improve from 0.00079
# Epoch 56/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.9157e-04 - val_loss: 8.4387e-04
#
# Epoch 00056: val_loss did not improve from 0.00079
# Epoch 57/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.8866e-04 - val_loss: 8.0179e-04
#
# Epoch 00057: val_loss did not improve from 0.00079
# Epoch 58/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.9343e-04 - val_loss: 7.8639e-04
#
# Epoch 00058: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 59/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.8227e-04 - val_loss: 8.5512e-04
#
# Epoch 00059: val_loss did not improve from 0.00079
# Epoch 60/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.8630e-04 - val_loss: 7.9351e-04
#
# Epoch 00060: val_loss did not improve from 0.00079
# Epoch 61/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.8028e-04 - val_loss: 8.1189e-04
#
# Epoch 00061: val_loss did not improve from 0.00079
# Epoch 62/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.7013e-04 - val_loss: 7.9365e-04
#
# Epoch 00062: val_loss did not improve from 0.00079
# Epoch 63/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.7562e-04 - val_loss: 7.7751e-04
#
# Epoch 00063: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 64/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.7342e-04 - val_loss: 7.8617e-04
#
# Epoch 00064: val_loss did not improve from 0.00078
# Epoch 65/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.6913e-04 - val_loss: 7.8432e-04
#
# Epoch 00065: val_loss did not improve from 0.00078
# Epoch 66/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.7563e-04 - val_loss: 7.9836e-04
#
# Epoch 00066: val_loss did not improve from 0.00078
# Epoch 67/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.6910e-04 - val_loss: 8.1359e-04
#
# Epoch 00067: val_loss did not improve from 0.00078
# Epoch 68/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.6350e-04 - val_loss: 8.0164e-04
#
# Epoch 00068: val_loss did not improve from 0.00078
# Epoch 69/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.6278e-04 - val_loss: 8.2019e-04
#
# Epoch 00069: val_loss did not improve from 0.00078
# Epoch 70/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.6463e-04 - val_loss: 7.8632e-04
#
# Epoch 00070: val_loss did not improve from 0.00078
# Epoch 71/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.6141e-04 - val_loss: 7.8224e-04
#
# Epoch 00071: val_loss did not improve from 0.00078
# Epoch 72/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.5999e-04 - val_loss: 7.9445e-04
#
# Epoch 00072: val_loss did not improve from 0.00078
# Epoch 73/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.5860e-04 - val_loss: 8.2463e-04
#
# Epoch 00073: val_loss did not improve from 0.00078
# Epoch 74/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.5570e-04 - val_loss: 8.0082e-04
#
# Epoch 00074: val_loss did not improve from 0.00078
# Epoch 75/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.5145e-04 - val_loss: 7.7117e-04
#
# Epoch 00075: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 76/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.5679e-04 - val_loss: 7.8544e-04
#
# Epoch 00076: val_loss did not improve from 0.00077
# Epoch 77/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.5018e-04 - val_loss: 7.8579e-04
#
# Epoch 00077: val_loss did not improve from 0.00077
# Epoch 78/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4715e-04 - val_loss: 7.9992e-04
#
# Epoch 00078: val_loss did not improve from 0.00077
# Epoch 79/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4957e-04 - val_loss: 8.0042e-04
#
# Epoch 00079: val_loss did not improve from 0.00077
# Epoch 80/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.4970e-04 - val_loss: 7.7365e-04
#
# Epoch 00080: val_loss did not improve from 0.00077
# Epoch 81/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4632e-04 - val_loss: 8.0737e-04
#
# Epoch 00081: val_loss did not improve from 0.00077
# Epoch 82/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.4725e-04 - val_loss: 7.7799e-04
#
# Epoch 00082: val_loss did not improve from 0.00077
# Epoch 83/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.4968e-04 - val_loss: 7.7630e-04
#
# Epoch 00083: val_loss did not improve from 0.00077
# Epoch 84/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4297e-04 - val_loss: 7.7346e-04
# Epoch 00084: val_loss did not improve from 0.00077
# Epoch 85/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4010e-04 - val_loss: 8.0104e-04
#
# Epoch 00085: val_loss did not improve from 0.00077
# Epoch 86/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4683e-04 - val_loss: 7.9380e-04
#
# Epoch 00086: val_loss did not improve from 0.00077
# Epoch 87/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4088e-04 - val_loss: 8.5219e-04
#
# Epoch 00087: val_loss did not improve from 0.00077
# Epoch 88/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.4481e-04 - val_loss: 7.8415e-04
#
# Epoch 00088: val_loss did not improve from 0.00077
# Epoch 89/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.3800e-04 - val_loss: 8.0190e-04
#
# Epoch 00089: val_loss did not improve from 0.00077
# Epoch 90/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.4036e-04 - val_loss: 8.4202e-04
#
# Epoch 00090: val_loss did not improve from 0.00077
# Epoch 91/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.3724e-04 - val_loss: 7.9857e-04
#
# Epoch 00091: val_loss did not improve from 0.00077
# Epoch 92/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.3301e-04 - val_loss: 7.7072e-04
#
# Epoch 00092: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 93/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.3304e-04 - val_loss: 8.2349e-04
#
# Epoch 00093: val_loss did not improve from 0.00077
# Epoch 94/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.3273e-04 - val_loss: 8.0446e-04
#
# Epoch 00094: val_loss did not improve from 0.00077
# Epoch 95/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.2966e-04 - val_loss: 8.1133e-04
#
# Epoch 00095: val_loss did not improve from 0.00077
# Epoch 96/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.3237e-04 - val_loss: 7.8880e-04
#
# Epoch 00096: val_loss did not improve from 0.00077
# Epoch 97/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.3021e-04 - val_loss: 8.0957e-04
#
# Epoch 00097: val_loss did not improve from 0.00077
# Epoch 98/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.2628e-04 - val_loss: 8.0219e-04
#
# Epoch 00098: val_loss did not improve from 0.00077
# Epoch 99/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.2930e-04 - val_loss: 7.9504e-04
#
# Epoch 00099: val_loss did not improve from 0.00077
# Epoch 100/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.2717e-04 - val_loss: 7.8920e-04
#
# Epoch 00100: val_loss did not improve from 0.00077
# Epoch 101/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.2338e-04 - val_loss: 8.2882e-04
#
# Epoch 00101: val_loss did not improve from 0.00077
# Epoch 102/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.2298e-04 - val_loss: 7.6756e-04
#
# Epoch 00102: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 103/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.2165e-04 - val_loss: 7.9255e-04
#
# Epoch 00103: val_loss did not improve from 0.00077
# Epoch 104/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.2238e-04 - val_loss: 7.8967e-04
#
# Epoch 00104: val_loss did not improve from 0.00077
# Epoch 105/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1884e-04 - val_loss: 7.9679e-04
#
# Epoch 00105: val_loss did not improve from 0.00077
# Epoch 106/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.2102e-04 - val_loss: 8.0211e-04
#
# Epoch 00106: val_loss did not improve from 0.00077
# Epoch 107/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.1908e-04 - val_loss: 7.8064e-04
#
# Epoch 00107: val_loss did not improve from 0.00077
# Epoch 108/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.1914e-04 - val_loss: 7.8174e-04
#
# Epoch 00108: val_loss did not improve from 0.00077
# Epoch 109/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.1983e-04 - val_loss: 7.6419e-04
#
# Epoch 00109: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 110/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.2038e-04 - val_loss: 7.9146e-04
#
# Epoch 00110: val_loss did not improve from 0.00076
# Epoch 111/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.2077e-04 - val_loss: 8.1883e-04
#
# Epoch 00111: val_loss did not improve from 0.00076
# Epoch 112/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.1491e-04 - val_loss: 7.9566e-04
#
# Epoch 00112: val_loss did not improve from 0.00076
# Epoch 113/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.1557e-04 - val_loss: 7.6774e-04
#
# Epoch 00113: val_loss did not improve from 0.00076
# Epoch 114/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.1559e-04 - val_loss: 8.1857e-04
#
# Epoch 00114: val_loss did not improve from 0.00076
# Epoch 115/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.1250e-04 - val_loss: 7.9828e-04
#
# Epoch 00115: val_loss did not improve from 0.00076
# Epoch 116/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1513e-04 - val_loss: 7.8450e-04
#
# Epoch 00116: val_loss did not improve from 0.00076
# Epoch 117/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.1403e-04 - val_loss: 7.9277e-04
#
# Epoch 00117: val_loss did not improve from 0.00076
# Epoch 118/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0944e-04 - val_loss: 7.8846e-04
#
# Epoch 00118: val_loss did not improve from 0.00076
# Epoch 119/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.1059e-04 - val_loss: 8.0204e-04
#
# Epoch 00119: val_loss did not improve from 0.00076
# Epoch 120/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.0494e-04 - val_loss: 8.0544e-04
#
# Epoch 00120: val_loss did not improve from 0.00076
# Epoch 121/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0927e-04 - val_loss: 7.8636e-04
#
# Epoch 00121: val_loss did not improve from 0.00076
# Epoch 122/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.0965e-04 - val_loss: 7.8426e-04
#
# Epoch 00122: val_loss did not improve from 0.00076
# Epoch 123/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.0418e-04 - val_loss: 7.8360e-04
#
# Epoch 00123: val_loss did not improve from 0.00076
# Epoch 124/150
# 1712/1712 [==============================] - 9s 6ms/step - loss: 1.0559e-04 - val_loss: 8.3168e-04
#
# Epoch 00124: val_loss did not improve from 0.00076
# Epoch 125/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.0379e-04 - val_loss: 7.8996e-04
#
# Epoch 00125: val_loss did not improve from 0.00076
# Epoch 126/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0539e-04 - val_loss: 8.2257e-04
#
# Epoch 00126: val_loss did not improve from 0.00076
# Epoch 127/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.0496e-04 - val_loss: 7.9713e-04
#
# Epoch 00127: val_loss did not improve from 0.00076
# Epoch 128/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0521e-04 - val_loss: 8.1194e-04
#
# Epoch 00128: val_loss did not improve from 0.00076
# Epoch 129/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0672e-04 - val_loss: 8.0947e-04
#
# Epoch 00129: val_loss did not improve from 0.00076
# Epoch 130/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 1.0311e-04 - val_loss: 8.0672e-04
#
# Epoch 00130: val_loss did not improve from 0.00076
# Epoch 131/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0310e-04 - val_loss: 7.6516e-04
#
# Epoch 00131: val_loss did not improve from 0.00076
# Epoch 132/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0284e-04 - val_loss: 8.2127e-04
#
# Epoch 00132: val_loss did not improve from 0.00076
# Epoch 133/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0352e-04 - val_loss: 7.9604e-04
# Epoch 00133: val_loss did not improve from 0.00076
# Epoch 134/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.5075e-05 - val_loss: 7.7366e-04
#
# Epoch 00134: val_loss did not improve from 0.00076
# Epoch 135/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0136e-04 - val_loss: 7.9065e-04
#
# Epoch 00135: val_loss did not improve from 0.00076
# Epoch 136/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.6073e-05 - val_loss: 8.1573e-04
#
# Epoch 00136: val_loss did not improve from 0.00076
# Epoch 137/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.9590e-05 - val_loss: 8.1823e-04
#
# Epoch 00137: val_loss did not improve from 0.00076
# Epoch 138/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.7440e-05 - val_loss: 7.9991e-04
#
# Epoch 00138: val_loss did not improve from 0.00076
# Epoch 139/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.9094e-05 - val_loss: 8.1230e-04
#
# Epoch 00139: val_loss did not improve from 0.00076
# Epoch 140/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.7072e-05 - val_loss: 8.1988e-04
#
# Epoch 00140: val_loss did not improve from 0.00076
# Epoch 141/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 9.7025e-05 - val_loss: 7.7948e-04
#
# Epoch 00141: val_loss did not improve from 0.00076
# Epoch 142/150
# 1712/1712 [==============================] - 10s 6ms/step - loss: 9.7288e-05 - val_loss: 7.9430e-04
#
# Epoch 00142: val_loss did not improve from 0.00076
# Epoch 143/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.8909e-05 - val_loss: 7.7290e-04
#
# Epoch 00143: val_loss did not improve from 0.00076
# Epoch 144/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.9322e-05 - val_loss: 8.1986e-04
#
# Epoch 00144: val_loss did not improve from 0.00076
# Epoch 145/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0269e-04 - val_loss: 7.8291e-04
#
# Epoch 00145: val_loss did not improve from 0.00076
# Epoch 146/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.7433e-05 - val_loss: 8.1674e-04
#
# Epoch 00146: val_loss did not improve from 0.00076
# Epoch 147/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.3403e-05 - val_loss: 7.8218e-04
#
# Epoch 00147: val_loss did not improve from 0.00076
# Epoch 148/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.3078e-05 - val_loss: 8.2075e-04
#
# Epoch 00148: val_loss did not improve from 0.00076
# Epoch 149/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.2578e-05 - val_loss: 7.9322e-04
#
# Epoch 00149: val_loss did not improve from 0.00076
# Epoch 150/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 9.2237e-05 - val_loss: 7.9919e-04
#
# Epoch 00150: val_loss did not improve from 0.00076

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。
#
# 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
#np.fliplr()的作用
#fliplr()是Numpy庫中的函數，作用是將數組在左右方向上翻轉.需要注意的是，fliplr()在左右方向上翻轉每行的元素，列保持不變，但是列的顯示順序變了.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv("training.csv")
data.head().T
# 過濾有缺失值的 row
data = data.dropna()

# 將圖片像素值讀取為 numpy array 的形態
data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

# 單獨把圖像 array 抽取出來
imgs = np.vstack(data['Image'].values)/255
# reshape 為 96 x 96
imgs = imgs.reshape(data.shape[0], 96, 96)
# 轉換為 float
imgs = imgs.astype(np.float32)

# 提取坐標的部分
points = data[data.columns[:-1]].values

# 轉換為 float
points = points.astype(np.float32)
point1 = points[0]

# normalize 坐標值到 [-0.5, 0.5]
points = points/96 - 0.5

plt.subplot( 1,2,1)      # 將窗口分為兩行一列四個子圖，則可顯示二幅圖片 
plt.title( ' origin image ' )    # 第一幅圖片標題 
plt.imshow(imgs[0], cmap='gray')       # 繪製第一幅圖片
plt.scatter(point1[0:30:2], point1[1:31:2], 10, c='red')

img2 = np.fliplr(imgs[0])
point2[0] = point1[2]
point2[2] = point1[0]
point2[4] = point1[8]
point2[6] = point1[10]
point2[8] = point1[4]
point2[10] = point1[6]
point2[12] = point1[16]
point2[14] = point1[18]
point2[16] = point1[12]
point2[18] = point1[14]
point2[20] = point1[20]  #鼻子一個,不flip
point2[22] = point1[24]
point2[24] = point1[22]
point2[26] = point1[26]  #口中央頂一個,不flip
point2[28] = point1[28]  #口中央頂一個,不flip

plt.subplot( 1,2,2)      # 第二個子圖 
plt.title( ' flip image ' )    # 第二幅圖片標題 
plt.imshow(img2, cmap='gray')       # 繪製第二幅圖片,且為灰度圖 
plt.scatter(point2[0:30:2], point1[1:31:2], 10, c='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-69ffea34d648> in <module>
#      44 point2[12] = point1[16]
#      45 point2[14] = point1[18]
# ---> 46 point2[16] = point1[12]
#      47 point2[18] = point1[14]
#      48 point2[20] = point1[20]  #鼻子一個,不flip
#
# IndexError: index 16 is out of bounds for axis 0 with size 15
